# %% [markdown]
# # In this notebook I will be following the proteomic workflow developed by Emma and documented by Sean here: http://rpubs.com/seanb80/237863

# %% [markdown]
# ## But FIRST, I need to add the following contaminant files to my database. I already put these files into the folder with all of my data in the previous notebook.
#
# 1) contam.bovin
# 2) contam.human
# 3) contam.other

# %%
cd ~/Documents/rhonda
# Out:
# /home/srlab/Documents/rhonda

# %%
ls
# Out:
# 000-Remotelogin_filechange.ipynb
# 001-Comet.ipynb
# 20161205_Sample_11A.mzXML
# 20161205_Sample_11A.pep.xml
# 20161205_Sample_11.mzXML
# 20161205_Sample_11.pep.xml
# 20161205_Sample_12A.mzXML
# 20161205_Sample_12A.pep.xml
# 20161205_Sample_12.mzXML
# 20161205_Sample_12.pep.xml
# 20161205_Sample_16A.mzXML
# 20161205_Sample_16A.pep.xml
# 20161205_Sample_16.mzXML
# 20161205_Sample_16.pep.xml
# 20161205_Sample_19A.mzXML
# 20161205_Sample_19A.pep.xml
# 20161205_Sample_19.mzXML
# 20161205_Sample_19.pep.xml
# 20161205_Sample_1A.mzXML
# 20161205_Sample_1A.pep.xml
# 20161205_sample_1.mzXML
# 20161205_sample_1.pep.xml
# 20161205_Sample_20A.mzXML
# 20161205_Sample_20A.pep.xml
# 20161205_Sample_20.mzXML
# 20161205_Sample_20.pep.xml
# 20161205_Sample_24A.mzXML
# 20161205_Sample_24A.pep.xml
# 20161205_Sample_24.mzXML
# 20161205_Sample_24.pep.xml
# 20161205_Sample_27A.mzXML
# 20161205_Sample_27A.pep.xml
# 20161205_Sample_27.mzXML
# 20161205_Sample_27.pep.xml
# 20161205_Sample_28A.mzXML
# ...

# %%
# !cat contam.bovin contam.human contam.other contigs.fasta.transdecoder.pep > contigs_contam.fasta.transdecoder.pep

# %%
ls
# Out:
# 000-Remotelogin_filechange.ipynb
# 001-Comet.ipynb
# 20161205_Sample_11A.mzXML
# 20161205_Sample_11A.pep.xml
# 20161205_Sample_11.mzXML
# 20161205_Sample_11.pep.xml
# 20161205_Sample_12A.mzXML
# 20161205_Sample_12A.pep.xml
# 20161205_Sample_12.mzXML
# 20161205_Sample_12.pep.xml
# 20161205_Sample_16A.mzXML
# 20161205_Sample_16A.pep.xml
# 20161205_Sample_16.mzXML
# 20161205_Sample_16.pep.xml
# 20161205_Sample_19A.mzXML
# 20161205_Sample_19A.pep.xml
# 20161205_Sample_19.mzXML
# 20161205_Sample_19.pep.xml
# 20161205_Sample_1A.mzXML
# 20161205_Sample_1A.pep.xml
# 20161205_sample_1.mzXML
# 20161205_sample_1.pep.xml
# 20161205_Sample_20A.mzXML
# 20161205_Sample_20A.pep.xml
# 20161205_Sample_20.mzXML
# 20161205_Sample_20.pep.xml
# 20161205_Sample_24A.mzXML
# 20161205_Sample_24A.pep.xml
# 20161205_Sample_24.mzXML
# 20161205_Sample_24.pep.xml
# 20161205_Sample_27A.mzXML
# 20161205_Sample_27A.pep.xml
# 20161205_Sample_27.mzXML
# 20161205_Sample_27.pep.xml
# 20161205_Sample_28A.mzXML
# ...

# %%
# !/home/shared/comet/comet.2016012.linux.exe -PPcomet.params.high-low -Dcontigs_contam.fasta.transdecoder.pep 20161205_sample_1.mzXML
# Out:
#  Comet version "2016.01 rev. 2"
#
#  Search start:  01/29/2017, 08:04:22 AM
#  - Input file: 20161205_sample_1.mzXML
#    - Load spectra: 89352
#  99%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:06:46 AM

# %%
# !/home/shared/comet/comet.2016012.linux.exe -PPcomet.params.high-low -Dcontigs_contam.fasta.transdecoder.pep 20161205_Sample_*.mzXML
# Out:
#  Comet version "2016.01 rev. 2"
#
#  Search start:  01/29/2017, 08:06:58 AM
#  - Input file: 20161205_Sample_11.mzXML
#    - Load spectra: 94172
#  99%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:09:29 AM
#
#  Search start:  01/29/2017, 08:09:30 AM
#  - Input file: 20161205_Sample_11A.mzXML
#    - Load spectra: 94326
#  99%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:12:03 AM
#
#  Search start:  01/29/2017, 08:12:05 AM
#  - Input file: 20161205_Sample_12.mzXML
#    - Load spectra: 97734
#  99%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:14:45 AM
#
#  Search start:  01/29/2017, 08:14:47 AM
#  - Input file: 20161205_Sample_12A.mzXML
#    - Load spectra: 97212
#  99%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:17:24 AM
#
#  Search start:  01/29/2017, 08:17:25 AM
#  - Input file: 20161205_Sample_16.mzXML
#    - Load spectra: 98031
# 100%
#      - Post analysis:  done
#  Search end:    01/29/2017, 08:20:04 AM
#
# ...

# %%
ls
# Out:
# 000-Remotelogin_filechange.ipynb
# 001-Comet.ipynb
# 20161205_Sample_11A.mzXML
# 20161205_Sample_11A.pep.xml
# 20161205_Sample_11.mzXML
# 20161205_Sample_11.pep.xml
# 20161205_Sample_12A.mzXML
# 20161205_Sample_12A.pep.xml
# 20161205_Sample_12.mzXML
# 20161205_Sample_12.pep.xml
# 20161205_Sample_16A.mzXML
# 20161205_Sample_16A.pep.xml
# 20161205_Sample_16.mzXML
# 20161205_Sample_16.pep.xml
# 20161205_Sample_19A.mzXML
# 20161205_Sample_19A.pep.xml
# 20161205_Sample_19.mzXML
# 20161205_Sample_19.pep.xml
# 20161205_Sample_1A.mzXML
# 20161205_Sample_1A.pep.xml
# 20161205_sample_1.mzXML
# 20161205_sample_1.pep.xml
# 20161205_Sample_20A.mzXML
# 20161205_Sample_20A.pep.xml
# 20161205_Sample_20.mzXML
# 20161205_Sample_20.pep.xml
# 20161205_Sample_24A.mzXML
# 20161205_Sample_24A.pep.xml
# 20161205_Sample_24.mzXML
# 20161205_Sample_24.pep.xml
# 20161205_Sample_27A.mzXML
# 20161205_Sample_27A.pep.xml
# 20161205_Sample_27.mzXML
# 20161205_Sample_27.pep.xml
# 20161205_Sample_28A.mzXML
# ...
